# %%
first="welcom sunyoung!"

# %%
first
# Out:
# 'welcom sunyoung!'

# %%
first='good day'

# %%
first
# Out:
# 'good day'

# %%
first=second

# %%
first
# Out:
# "Life is simple 'really?'"

# %%
second
# Out:
# "Life is simple 'really?'"

# %%
third="life is"+'good!'

# %%
third
# Out:
# 'life isgood!'

# %%
third="life is "+ first

# %%
third
# Out:
# 'life is welcom sunyoung!'

# %%
second="life is good!"

# %%
third=first + " "+ second

# %%
third
# Out:
# 'welcom sunyoung! life is good!'

# %% [markdown]
# ## 문제풀이
#
# - 두 문자열 변수를 선언해서 각각 변수에 값을 넣고 저장한 뒤,+ 기호를 이용해 이어 붙이는 코드를 작성해 보세요.
#
#
# - 변수 이름:first,second,result
#
# - 결과) 'Good Moning'

# %%
first = "good  "

# %%
first
# Out:
# 'good'

# %%
second = ' Moning'

# %%
second
# Out:
# 'Moning'

# %%
result= first + second

# %%
result
# Out:
# 'goodMoning'
