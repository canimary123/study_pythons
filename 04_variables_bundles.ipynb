# %% [markdown]
# 🟩 문제 1. 리스트 만들기
# 회사원 이름을 순서대로 리스트에 저장해 보세요.
#  리스트 이름: employees
# 번호
# 이름
# 1
# Alice
# 2
# Bob
# 3
# Charlie
# 4
# Diana
#
# # employees 리스트를 만들어 보세요
# # Alice 출력
# # Charlie 출력

# %%
employees_01 = {"번호" : "1",
"이름" : " Alice"}

# %%
employees_02 = {"번호" : "2",
"이름" : " bob"}

# %%
employees_03 = {"번호" : "3",
"이름" : " Charlie"}

# %%
employees_04 = {"번호" : "4",
"이름" : "  Diana"}

# %%
employees = [ "employees_01 ","employees_03 "]

# %%
employees
# Out:
# ['employees_01 ', 'employees_03 ']

# %% [markdown]
# 🟩 문제 2. 딕셔너리 만들기
# 한 명의 회사원 정보를 딕셔너리로 만들어 보세요.
#  딕셔너리 이름: employee1
# 키
# 값
# name
# Alice
# department
# Sales
# position
# Manager
# year
# 2023
#
# # employee1 딕셔너리를 만들어 보세요
# # “Manager” 를 출력
#
# name
# department
# position
# year
# Alice
# Sales
# Manager
# 2023
# Bob
# IT
# Engineer
# 2022
# Charlie
# HR
# Staff
# 2023
# Diana
# Marketing
# Analyst
# 2024

# %% [markdown]
# 🟩 문제 3. 리스트 안 딕셔너리 만들기
# 여러 회사원의 정보를 리스트 안 딕셔너리 형태로 만들어 보세요.
#  리스트 이름: all_employees# all_employees 리스트 안에 딕셔너리를 만들어 보세요
# # 3 번째 직원 정보 출력
# # 2 번째 position 출력
